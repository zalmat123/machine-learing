# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
sns.countplot(x="Survived", data=df)
plt.show()

# %%
sns.countplot(x="Pclass",data=df)
plt.show()

# %%
sns.countplot(x="Age",data=df)
plt.show()

# %%
sns.countplot(x="Sex",data=df)

# %%
sns.catplot(x="Sex",hue="Survived", kind="count",data=df)
plt.show()

# %%
sns.catplot(x="Pclass",hue="Survived", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="Pclass",hue="Sex", kind="count",data=df)
plt.show()

# %%
sns.violinplot(x="Sex",y="Age", hue="Survived", data=df,split=True)
plt.show()

# %%
sns.violinplot(x="Sex",y="Age", hue="Pclass", data=df)
plt.show()

# %%
sns.violinplot(x="Age",y="Sex", hue="Survived", data=df,split=True)
plt.show()

# %% [markdown]
# Finding the missing value

# %%
# missing value 
# create the data frame
# np.nan ==> not a number
z1=[1,np.nan,np.nan,4,5,np.nan,7,np.nan]
z2=[1,1,1,1,2,2,2,2]
#the above two z are a list
# now create the dataframe the like the following
df1 = pd.DataFrame({"Cricket":z1,
                   "Tennis":z2})

# %%
df1
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2
# 5      NaN       2
# 6      7.0       2
# 7      NaN       2

# %%
df1.fillna(value=0)
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      0.0       1
# 2      0.0       1
# 3      4.0       1
# 4      5.0       2
# 5      0.0       2
# 6      7.0       2
# 7      0.0       2

# %%
df1
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2
# 5      NaN       2
# 6      7.0       2
# 7      NaN       2

# %%
df1.fillna(2)
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      2.0       1
# 2      2.0       1
# 3      4.0       1
# 4      5.0       2
# 5      2.0       2
# 6      7.0       2
# 7      2.0       2

# %%
df1.fillna(4.25)
# Out:
#    Cricket  Tennis
# 0     1.00       1
# 1     4.25       1
# 2     4.25       1
# 3     4.00       1
# 4     5.00       2
# 5     4.25       2
# 6     7.00       2
# 7     4.25       2

# %%
df1['Cricket'].mean()
# Out:
# 4.25

# %%
df1
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2
# 5      NaN       2
# 6      7.0       2
# 7      NaN       2

# %%
df1.fillna(df1['Cricket'].mean())
# Out:
#    Cricket  Tennis
# 0     1.00       1
# 1     4.25       1
# 2     4.25       1
# 3     4.00       1
# 4     5.00       2
# 5     4.25       2
# 6     7.00       2
# 7     4.25       2

# %%
df1[:4].mean()
# Out:
# Cricket    2.5
# Tennis     1.0
# dtype: float64

# %%
df1['Cricket'].fillna(df1.groupby(['Tennis'])['Cricket'].transform(np.mean))
# Out:
# 0    1.0
# 1    2.5
# 2    2.5
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    6.0
# Name: Cricket, dtype: float64

# %% [markdown]
# <!-- how -->

# %% [markdown]
# <!-- how -->

# %%
df.head()
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2

# %%
df1
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2
# 5      NaN       2
# 6      7.0       2
# 7      NaN       2

# %%
df
# Out:
#    Cricket  Tennis
# 0      1.0       1
# 1      NaN       1
# 2      NaN       1
# 3      4.0       1
# 4      5.0       2
# 5      NaN       2
# 6      7.0       2
# 7      NaN       2

# %%
df = pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
#
# [2 rows x 12 columns]

# %%
df.head(891)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ***statistics and probability***
# 1. Descriptive statistcics
# 2. Inferential ststistics
#
# Descriptive statistics is making a description depends on the data we have.
#
#
# 1.   mean
# 2. media
# 3. mode
# 4. percentile
# 5. range
#
#
#
# Inferential: it used to specify the baviour.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]
