# %%
print("this is fitsum mesfin")
# Out:
# this is fitsum mesfin

# %%
import pandas as pd
df = pd.read_csv("/content/mtcars.csv")
print(df)
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.head(3)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  ...  qsec  vs  am  gear  carb
# 27    Lotus Europa  30.4    4   95.1  113  ...  16.9   1   1     5     2
# 28  Ford Pantera L  15.8    8  351.0  264  ...  14.5   0   1     5     4
# 29    Ferrari Dino  19.7    6  145.0  175  ...  15.5   0   1     5     6
# 30   Maserati Bora  15.0    8  301.0  335  ...  14.6   0   1     5     8
# 31      Volvo 142E  21.4    4  121.0  109  ...  18.6   1   1     4     2
#
# [5 rows x 12 columns]

# %%
df[0:4]
# Out:
#             model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0       Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2      Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3  Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
#
# [4 rows x 12 columns]

# %%
df[0:1]
# Out:
#        model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 0  Mazda RX4  21.0    6  160.0  110   3.9  2.62  16.46   0   1     4     4

# %%
df.head(1)
# Out:
#        model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 0  Mazda RX4  21.0    6  160.0  110   3.9  2.62  16.46   0   1     4     4

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df['model']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df['mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.disp
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: disp, dtype: float64

# %%
x_value = df['model']
y_value = df['disp']
x_value
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %%
Series = pd.DataFrame(df)

# %%
print(Series)
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
Series.plot()

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df['total'] = df['mpg']+df['cyl']

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  ...  vs  am  gear  carb  total
# 0             Mazda RX4  21.0    6  160.0  110  ...   0   1     4     4   27.0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...   0   1     4     4   27.0
# 2            Datsun 710  22.8    4  108.0   93  ...   1   1     4     1   26.8
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...   1   0     3     1   27.4
# 4     Hornet Sportabout  18.7    8  360.0  175  ...   0   0     3     2   26.7
# 5               Valiant  18.1    6  225.0  105  ...   1   0     3     1   24.1
# 6            Duster 360  14.3    8  360.0  245  ...   0   0     3     4   22.3
# 7             Merc 240D  24.4    4  146.7   62  ...   1   0     4     2   28.4
# 8              Merc 230  22.8    4  140.8   95  ...   1   0     4     2   26.8
# 9              Merc 280  19.2    6  167.6  123  ...   1   0     4     4   25.2
# 10            Merc 280C  17.8    6  167.6  123  ...   1   0     4     4   23.8
# ...

# %%
df.drop(columns=['total'])
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
df[['model','disp']]
# Out:
#                   model   disp
# 0             Mazda RX4  160.0
# 1         Mazda RX4 Wag  160.0
# 2            Datsun 710  108.0
# 3        Hornet 4 Drive  258.0
# 4     Hornet Sportabout  360.0
# 5               Valiant  225.0
# 6            Duster 360  360.0
# 7             Merc 240D  146.7
# 8              Merc 230  140.8
# 9              Merc 280  167.6
# 10            Merc 280C  167.6
# 11           Merc 450SE  275.8
# 12           Merc 450SL  275.8
# 13          Merc 450SLC  275.8
# 14   Cadillac Fleetwood  472.0
# 15  Lincoln Continental  460.0
# 16    Chrysler Imperial  440.0
# 17             Fiat 128   78.7
# 18          Honda Civic   75.7
# 19       Toyota Corolla   71.1
# 20        Toyota Corona  120.1
# 21     Dodge Challenger  318.0
# 22          AMC Javelin  304.0
# 23           Camaro Z28  350.0
# 24     Pontiac Firebird  400.0
# 25            Fiat X1-9   79.0
# 26        Porsche 914-2  120.3
# 27         Lotus Europa   95.1
# 28       Ford Pantera L  351.0
# ...
