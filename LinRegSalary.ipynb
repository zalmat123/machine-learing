# %%
#import the library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import the dataset
df = pd.read_csv("/content/Salary_Data.csv")
x = df.iloc[:, 0].values.reshape(-1,1)
#reshape(30,1) is the same as reshape(-1,1) by indexing concept
y = df.iloc[:, 1].values

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
x.shape
# Out:
# (30, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size =0.2, random_state =0)

# %%
from sklearn.linear_model import LinearRegression
Lin = LinearRegression()
Lin.fit(x_train,y_train)
Lin.coef_
# Out:
# array([9312.57512673])

# %%
x_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7]])

# %%
Lin.predict(x_test)
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
y_test
x_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7]])

# %%
plt.plot(x_test,Lin.predict(x_test))
plt.scatter(x_test,y_test, color="r")
plt.show()

# %%
Lin.predict([[2]])
# Out:
# array([44344.20519397])

# %%
Lin.predict([[30]])
# Out:
# array([306157.3529525])

# %%
Lin.predict([[0]])
# Out:
# array([26780.09915063])

# %%
Lin.predict([[12]])
# Out:
# array([138531.00067138])

# %% [markdown]
# Error Evaluation techniques
# 1. MAE=> mean absolute error
# 2. MSE=> mean squared erro

# %%
pred_y = Lin.predict(x_test)
pred_y -y_test
# Out:
# array([ 3017.96184072,   308.62295594,  7880.65717022,  -118.85785513,
#        -1719.43714544, -1631.49724683])

# %%
np.abs(pred_y -y_test)
# Out:
# array([3017.96184072,  308.62295594, 7880.65717022,  118.85785513,
#        1719.43714544, 1631.49724683])

# %%
mae = np.average(np.abs(pred_y -y_test))

# %%
mae
# Out:
# 2446.1723690465055

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test,pred_y)

# %%
Lin.predict([[6.5]])
# Out:
# array([87311.83747437])

# %%
mse = metrics.mean_squared_error(y_test,pred_y)

# %%
mse
# Out:
# 12823412.298126549
