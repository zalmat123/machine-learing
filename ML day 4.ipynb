# %%
# library to be imported
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# import the data to be analyized
df = pd.read_csv("/content/Salary_Data.csv")

# %%
# check  whether the data is present or not
df.head(4)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0

# %%
# separate a data set into input and output
input = df.iloc[:,0].values.reshape(-1,1)
input
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
input.shape
# Out:
# (30, 1)

# %%
output = df.iloc[:, 1].values.reshape(-1,1)
output
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %%
#training part
from sklearn.model_selection import train_test_split

# %%
train_x , test_x, train_y, test_y = train_test_split(input, output, train_size = 0.8, test_size=0.2, random_state=0)

# %%
train_x
# Out:
# array([[ 9.6],
#        [ 4. ],
#        [ 5.3],
#        [ 7.9],
#        [ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
test_y
# Out:
# array([[ 37731.],
#        [122391.],
#        [ 57081.],
#        [ 63218.],
#        [116969.],
#        [109431.]])

# %%
test_x
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7]])

# %%
train_y
# Out:
# array([[112635.],
#        [ 55794.],
#        [ 83088.],
#        [101302.],
#        [ 56642.],
#        [ 66029.],
#        [ 64445.],
#        [ 61111.],
#        [113812.],
#        [ 91738.],
#        [ 46205.],
#        [121872.],
#        [ 60150.],
#        [ 39891.],
#        [ 81363.],
#        [ 93940.],
#        [ 57189.],
#        [ 54445.],
#        [105582.],
#        [ 43525.],
#        [ 39343.],
#        [ 98273.],
#        [ 67938.],
#        [ 56957.]])

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn.linear_model import LinearRegression
Lin = LinearRegression()
Lin.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict_y = Lin.predict(test_x)
predict_y
# Out:
# array([[ 40748.96184072],
#        [122699.62295594],
#        [ 64961.65717022],
#        [ 63099.14214487],
#        [115249.56285456],
#        [107799.50275317]])

# %%
test_y
# Out:
# array([[ 37731.],
#        [122391.],
#        [ 57081.],
#        [ 63218.],
#        [116969.],
#        [109431.]])
