# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/LSM1.csv")

# %%
df.head(3)
# Out:
#    X  Y
# 0  1  2
# 1  2  4
# 2  3  5

# %%
x = df.iloc[:,0].values.reshape(1,-1);
x
# Out:
# array([[1, 2, 3, 4, 5]])

# %%
x.shape
# Out:
# (1, 5)
