# %%
# Import Library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import libraries for preparing model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# import libraries for logistic regression
from sklearn.linear_model import LogisticRegression

# %%
# Load the dataset
df = pd.read_csv("/content/diabetes.csv");

# %%
# show the information on the fields
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
# check if there is a null value
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# show distribution of various column
df.hist()
plt.show()

# %%
# split dataset into the input and out put (x is an input, y is an output)
y = df['Outcome'];
x = df.iloc[:,:-2]

# %%
# split X and Y into training and testsing sets
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# instantiate the model or create an object
log_reg = LogisticRegression()

# %%
# fit the model with data or train the model
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# predict the values
y_pred = log_reg.predict(x_test)

# %%
# display the confusion matrix to determine model accuracy
cnf_matrix = metrics.confusion_matrix(y_test,y_pred)

# %%
cnf_matrix
# Out:
# array([[97, 10],
#        [19, 28]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8116883116883117
