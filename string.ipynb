# %%
print("Fitsum Mesfin")
# Out:
# Fitsum Mesfin

# %%
print('Fitsum Mesfin')
# Out:
# Fitsum Mesfin

# %%
name = "Fitsum Mesfin"

# %%
print(name)
# Out:
# Fitsum Mesfin

# %%
name = 'Fitsum Mesfin'

# %%
print(name)
# Out:
# Fitsum Mesfin

# %%
print(len(name))
# Out:
# 13

# %%
for i in name:
  print(i)
# Out:
# F
# i
# t
# s
# u
# m
#
# M
# e
# s
# f
# i
# n

# %%
name = name.capitalize()
print(name)
# Out:
# Fitsum mesfin

# %%
name=name.upper()

# %%
print(name)
# Out:
# FITSUM MESFIN

# %%
name = name.lower()
print(name)
# Out:
# fitsum mesfin

# %%
name = name.casefold()
print(name)
# Out:
# fitsum mesfin

# %%
name= "FASIL MESFIN"
name = name.casefold()
print(name)
# Out:
# fasil mesfin

# %%
name = name.center(20)

# %%
print(name)
# Out:
#     fasil mesfin

# %%
print(len(name))
# Out:
# 20

# %%
name = "FASIL MESFIN"

# %%
print(name)
# Out:
# FASIL MESFIN

# %%
print(len(name))
# Out:
# 12

# %%
name = name.center(12)

# %%
print(name)
# Out:
# FASIL MESFIN

# %%
print(len(name))
# Out:
# 12

# %%
name = name.center(20)

# %%
print(len(name))
# Out:
# 20

# %%
print(name)
# Out:
#     FASIL MESFIN

# %%
name = name+"fasil mesfin"
print(name)
# Out:
#     FASIL MESFIN     fasil mesfin fasil mesfin fasil mesfinfasil mesfin

# %%
print(name)
# Out:
#     FASIL MESFIN     fasil mesfin fasil mesfin fasil mesfin

# %%
print(len(name))
# Out:
# 33

# %%
name = name.center(20)

# %%
print(name)
# Out:
#     FASIL MESFIN     fasil mesfin

# %%
print(len(name))
# Out:
# 33

# %%
if "fasil" in name:
  print(name)
# Out:
#     FASIL MESFIN     fasil mesfin fasil mesfin fasil mesfinfasil mesfin

# %%
if "fasilen" not in name:
  print("Note")
# Out:
# Note

# %%
if "Mesfin" in name:
  print("yes")
else:
  print("no")
# Out:
# no

# %%
name = ['fitsum', 'mesfin', 'chala','abreham','temam', 'bemnet']
print(name)
# Out:
# ['fitsum', 'mesfin', 'chala', 'abreham', 'temam', 'bemnet']

# %%
for i in name:
  print(f"\n {i}")
# Out:
#  fitsum
#
#  mesfin
#
#  chala
#
#  abreham
#
#  temam
#
#  bemnet

# %%
length_error ="the number of the character should be between 5 and 12"
user = input("please enter your  name: ")
if len(user)<5:
  raise Exception("The length of the name should be greater than 5")
elif len(user)>12:
  raise Exception("The length of the name should be lessthan 12")
else:
  print("Correct")
# Out:
# please enter your  name: fitsum emsdfhjkhf
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-53-6837d0204c05> in <module>()
#       4   raise Exception("The length of the name should be greater than 5")
#       5 elif len(user)>12:
# ----> 6   raise Exception("The length of the name should be lessthan 12")
#       7 else:
#       8   print("Correct")
#
# Exception: The length of the name should be lessthan 12
